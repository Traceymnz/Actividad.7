# %% [markdown]
# # Prácticas Profesionalizantes 2024
# EEST 9
#
# # Filtramos datos y generamos mapas

# %% [markdown]
# ## Trabajo en grupo entre 2 o 3 estudiantes
# Indicar los nombres y los links de los repositorios de la actividad 3 de los integrantes:
# * nombre - repositorio

# %% [markdown]
# # Seguimos trabajando con estos datasets

# %% [markdown]
# * [Aeropuertos Argentina](https://archivos.linti.unlp.edu.ar/index.php/s/vd9SIytO2ABbkAo).
#     * Nombre del archivo: ar-airports.csv
#     * Descargado de: https://ourairports.com/countries/AR/airports.csv
# * [Áreas protegidas](https://archivos.linti.unlp.edu.ar/index.php/s/Eqw1eAVC1pdefmb).
#     * Nombre del archivo: area_protegida.csv
#     * Descargado de: https://dnsg.ign.gob.ar/apps/api/v1/capas-sig/Geodesia+y+demarcaci%C3%B3n/L%C3%ADmites/area_protegida/csv
# * [Conectivdad Argentina](https://archivos.linti.unlp.edu.ar/index.php/s/3k2TO5sSzaAU6IY).
#     * Nombre del archivo: Conectividad_Internet.csv
#     * Descargado de :https://datos.gob.ar/dataset/enacom-conectividad-al-servicio-internet/archivo/enacom_CONEC-AL-SERVI-DE-INTER_0
# * [Datos sobre consumo cultural](https://archivos.linti.unlp.edu.ar/index.php/s/pf8NMFtr1bwxFtT).
#     * Nombre del archivo: encc_2017.csv
#     * Descargado de: https://datos.cultura.gob.ar/dataset/encuesta-nacional-de-consumos-culturales
# * [Avistajes de felinos en Argentina](https://archivos.linti.unlp.edu.ar/index.php/s/5iC9FrYWiGi11d0).
#     * Nombre del archivo: felinos_filtrado.csv
#     * Descargado de: https://www.gbif.org/

# %% [markdown]
# # Veamos otros ejemplos para filtrar datos

# %%
import pandas as pd
file_data = pd.read_csv('lagos_arg.csv')
file_data.Ubicación.unique()
# Out:
# array(['Santa Cruz', 'Río Negro / Neuquén', 'Chubut', 'Buenos Aires',
#        'Río Negro', 'Neuquén',
#        'Tierra del Fuego, Antártida e Islas del Atlántico Sur'],
#       dtype=object)

# %% [markdown]
# # 1. Quiero saber cuáles son los lagos de la provincia de Chubut

# %% [markdown]
# Veamos un ejemplo donde consulto sobre los lagos de la provincia de **Santa Cruz**

# %%
file_data[file_data.Ubicación=='Santa Cruz']
# Out:
#                     Nombre   Ubicación  Superficie (km²)  \
# 0           Lago Argentino  Santa Cruz              1435
# 1              Lago Viedma  Santa Cruz              1166
# 4             Lago Cardiel  Santa Cruz               358
# 7             Lago Strobel  Santa Cruz               100
# 12               Lago Ghío  Santa Cruz                65
# 17            Lago Quiroga  Santa Cruz                47
# 19             Lago Nansen  Santa Cruz                42
# 20           Lago Belgrano  Santa Cruz                42
# 22            Lago Posadas  Santa Cruz                41
# 26  Lago Salitroso o Sucio  Santa Cruz                37
# 28                Lago Tar  Santa Cruz                30
# 32  Lago Asador o Guitarra  Santa Cruz                23
# 37      Lago Quiroga Chico  Santa Cruz                20
# 42              Lago Azara  Santa Cruz                16
# 43         Lago Burmeister  Santa Cruz                14
# 44             Lago Onelli  Santa Cruz                14
#
#     Profundidad máxima (m)  Profundidad media (m)            Coordenadas
# 0                    500.0                  150.0  50°14'53"S 72°38'43"O
# 1                      NaN                    NaN  49°37'27"S 72°29'42"O
# 4                      NaN                   49.0   48°55'3"S 71°12'53"O
# 7                      NaN                    NaN  48°25'58"S 71°11'25"O
# 12                     NaN                    NaN  47°17'18"S 71°31'49"O
# 17                     NaN                    NaN    48°25'1"S 71°33'3"O
# 19                     NaN                    NaN  47°58'44"S 72°21'11"O
# 20                     NaN                    NaN   47°50'38"S 72°8'34"O
# 22                     NaN                   31.0  47°29'40"S 71°49'55"O
# 26                     NaN                    NaN   47°30'0"S 71°36'48"O
# 28                     NaN                    NaN    49°13'42"S 72°1'2"O
# 32                     NaN                    NaN  47°51'45"S 71°28'13"O
# 37                     NaN                    NaN   48°29'57"S 71°35'5"O
# 42                     NaN                    NaN  47°50'45"S 72°16'13"O
# 43                     NaN                    NaN   47°57'20"S 72°12'9"O
# 44                     NaN                    NaN   50°6'30"S 73°20'59"O

# %% [markdown]
# Realizá la consulta para ver los lagos de la provincia de **Chubut**

# %%
#acá arma la respuesta
import pandas as pd
file_data=pd.read_csv('lagos_arg.csv')
file_data[file_data.Ubicación=='Chubut']
# Out:
#                Nombre Ubicación  Superficie (km²)  Profundidad máxima (m)  \
# 3        Lago Musters    Chubut               427                    39.0
# 8        Lago Fontana    Chubut                84                     NaN
# 11      Lago La Plata    Chubut                73                     NaN
# 13      Lago Menéndez    Chubut                58                   287.0
# 18         Lago Puelo    Chubut                47                   180.0
# 21  Lago Futalaufquen    Chubut                42                   168.0
# 30        Lago Blanco    Chubut                28                     NaN
# 33     Lago Rivadavia    Chubut                23                   147.0
# 36     Lago Río Chico    Chubut                20                     NaN
# 38        Lago Epuyén    Chubut                17                   148.0
# 40       Lago Cholila    Chubut                17                   108.0
# 49     Lago Pico Nº 1    Chubut                10                     NaN
# 51       Lago Rosario    Chubut                10                    57.0
#
#     Profundidad media (m)            Coordenadas
# 3                    20.0  45°24'53"S 69°11'52"O
# 8                    79.0  44°55'17"S 71°29'45"O
# 11                    NaN  44°51'33"S 71°49'12"O
# 13                  149.0  42°41'28"S 71°51'45"O
# 18                  111.0    42°9'3"S 71°38'59"O
# 21                  101.0  42°49'42"S 71°40'31"O
# 30                    NaN  45°53'16"S 71°13'25"O
# 33                  104.0  42°36'39"S 71°39'59"O
# 36                    NaN  45°35'40"S 68°32'52"O
# 38                   92.0  42°11'15"S 71°30'24"O
# 40                   49.0   42°27'31"S 71°40'9"O
# 49                    NaN   44°14'31"S 71°30'8"O
# 51                   25.0  43°15'36"S 71°20'48"O

# %% [markdown]
# # 3. Utilizando el dataset elegido filtrar datos por algún criterio:
# * indicar qué criterios utilizaron

# %%
import pandas as pd
file_data=pd.read_csv('ar-airports(1).csv')
file_data[(file_data.type=='large_airport') & (file_data['latitude_deg']<15)]
# Out:
#      id ident           type                                      name  \
# 0  5781  SAEZ  large_airport  Minister Pistarini International Airport
# 1  5771  SABE  large_airport                     Jorge Newbery Airpark
#
#    latitude_deg  longitude_deg  elevation_ft continent country_name  \
# 0      -34.8222       -58.5358          67.0        SA    Argentina
# 1      -34.5592       -58.4156          18.0        SA    Argentina
#
#   iso_country  ...           municipality scheduled_service gps_code  \
# 0          AR  ...  Buenos Aires (Ezeiza)                 1     SAEZ
# 1          AR  ...           Buenos Aires                 1     SABE
#
#   iata_code  local_code                           home_link  \
# 0       EZE         EZE  http://www.aa2000.com.ar/index.php
# 1       AEP         AER                                 NaN
#
#                                       wikipedia_link     keywords score  \
# 0  https://en.wikipedia.org/wiki/Ministro_Pistari...  BUE, Ezeiza  1275
# 1  https://en.wikipedia.org/wiki/Aeroparque_Jorge...          NaN  1050
#
#                 last_updated
# 0  2022-10-27T15:05:29+00:00
# 1  2021-10-07T15:55:36+00:00
#
# [2 rows x 23 columns]

# %% [markdown]
# ### ¿Cómo podemos filtrar por más de un criterio?

# %%
file_data[(file_data.Ubicación=='Santa Cruz') & (file_data['Superficie (km²)']<15)]
# Out:
#              Nombre   Ubicación  Superficie (km²)  Profundidad máxima (m)  \
# 43  Lago Burmeister  Santa Cruz                14                     NaN
# 44      Lago Onelli  Santa Cruz                14                     NaN
#
#     Profundidad media (m)           Coordenadas Sup Tamaño Latitud en GMS  \
# 43                    NaN  47°57'20"S 72°12'9"O      chico     47°57'20"S
# 44                    NaN  50°6'30"S 73°20'59"O      chico      50°6'30"S
#
#    Longitud en GMS  Latitud en GD  Longitud en GD
# 43       72°12'9"O     -47.955556      -72.202500
# 44      73°20'59"O     -50.108333      -73.349722

# %% [markdown]
# Aca estamos filtrando por:
# * la provincia de **Santa Cruz** y la **superficie** sea mayor a 15
# * las columnas donde hago las consultas para filtrar son: **Ubicación** y **Superficie (km²)**

# %% [markdown]
# # 4. ¿Qué lago de Tierra del Fuego , Antártida e Islas del Atlántico Sur tiene una superficie mayor a 40?

# %%
# arma acá la respuesta

# %% [markdown]
# ## Veamos nuestros datos en un mapa

# %%
import folium

# %% [markdown]
# ¿Está instalado?

# %% [markdown]
# ## Primero: Tenemos que ubicar donde en qué **columnas** están los datos de :
# * latitud
# * longitud

# %%
file_data.columns
# Out:
# Index(['Nombre', 'Ubicación', 'Superficie (km²)', 'Profundidad máxima (m)',
#        'Profundidad media (m)', 'Coordenadas', 'Sup Tamaño', 'Latitud en GMS',
#        'Longitud en GMS', 'Latitud en GD', 'Longitud en GD'],
#       dtype='object')

# %% [markdown]
# En este caso las columnas con las **coordendas** son:
# * 'Latitud en GD'
# * 'Longitud en GD'

# %% [markdown]
# ## Segundo vamos a generar un mapa **base** para luego agregar los puntos

# %%
def generar_mapa():
    attr = (
        '&copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> '
        'contributors, &copy; <a href="https://cartodb.com/attributions">CartoDB</a>'
    )

    tiles = 'https://wms.ign.gob.ar/geoserver/gwc/service/tms/1.0.0/capabaseargenmap@EPSG%3A3857@png/{z}/{x}/{-y}.png'
    m = folium.Map(
        location=(-33.457606, -65.346857),
        control_scale=True,
        zoom_start=5,
        name='es',
        tiles=tiles,
        attr=attr
    )
    return m

# %% [markdown]
# Usamos la función **generar_mapa** para tener nuestro mapa base

# %%
mapa = generar_mapa()

# %% [markdown]
# La variable **mapa** es nuestra mapa **base**

# %% [markdown]
# ### Tercero agregamos a nuestro mapa:
# En la celda de abajo pusimos el código para poder agregar los puntos, te contamos lo más importante para tener en cuenta.
# * los puntos que se encuentran en las columnas de las **coordenadas**
# ```python
# [row['Latitud en GD'], row['Longitud en GD']],
# ```
# * queremos que muestre el nombre del lago cuando hacemos clic sobre cada icono, por eso pusimos el nombre de la columna donde se encuentra **ese dato**
# ```python
# popup=row['Nombre']
# ```

# %%
mapa = generar_mapa()
def agregar_marca_lago(row):
    folium.Marker(
        [row['Latitud en GD'], row['Longitud en GD']],
        popup=row['Nombre'],
        icon=folium.Icon()
        ).add_to(mapa)
file_data.apply(agregar_marca_lago, axis=1)
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_783d93e2b63328be739a31aa3aa462e8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_783d93e2b63328be739a31aa3aa462e8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_783d93e2b63328be739a31aa3aa462e8 = L.map(
#                 &quot;map_783d93e2b63328be739a31aa3aa462e8&quot;,
#                 {
#                     center: [-33.457606, -65.346857],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     name: &quot;es&quot;,
#                 }
#             );
#             L.control.scale().addTo(map_783d93e2b63328be739a31aa3aa462e8);
#
#
#
#
#
#             var tile_layer_f35af73832098c0cf4a84e803d5679de = L.tileLayer(
#                 &quot;https://wms.ign.gob.ar/geoserver/gwc/service/tms/1.0.0/capabaseargenmap@EPSG%3A3857@png/{z}/{x}/{-y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors, \u0026copy; \u003ca href=\&quot;https://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f35af73832098c0cf4a84e803d5679de.addTo(map_783d93e2b63328be739a31aa3aa462e8);
#
#
#             var marker_2bd55aa80931ba83decda37c374616a1 = L.marker(
#                 [-50.24805555555556, -72.64527777777778],
#                 {}
#             ).addTo(map_783d93e2b63328be739a31aa3aa462e8);
#
#
#             var icon_da2c21e33a060fb0ba2824634463f83a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2bd55aa80931ba83decda37c374616a1.setIcon(icon_da2c21e33a060fb0ba2824634463f83a);
#
#
#         var popup_5ea087448fbd19545a56cfb4726ac72c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_59a8f2ba12b6628e8c496676e6e691af = $(`&lt;div id=&quot;html_59a8f2ba12b6628e8c496676e6e691af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lago Argentino&lt;/div&gt;`)[0];
#                 popup_5ea087448fbd19545a56cfb4726ac72c.setContent(html_59a8f2ba12b6628e8c496676e6e691af);
#
#
#
#         marker_2bd55aa80931ba83decda37c374616a1.bindPopup(popup_5ea087448fbd19545a56cfb4726ac72c)
#         ;
#
#
#
#
#             var marker_7825bc17482eda9da3b6ce797faa257f = L.marker(
#                 [-49.62416666666667, -72.495],
#                 {}
#             ).addTo(map_783d93e2b63328be739a31aa3aa462e8);
#
#
#             var icon_a983808a6952dc4aaf66a2e2c795f85d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7825bc17482eda9da3b6ce797faa257f.setIcon(icon_a983808a6952dc4aaf66a2e2c795f85d);
#
#
#         var popup_c47bcff7cbf63c5cc4fabb4aebee141e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_65c9f7be2f3b04c0ec81e5db26b5a4a1 = $(`&lt;div id=&quot;html_65c9f7be2f3b04c0ec81e5db26b5a4a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lago Viedma&lt;/div&gt;`)[0];
#                 popup_c47bcff7cbf63c5cc4fabb4aebee141e.setContent(html_65c9f7be2f3b04c0ec81e5db26b5a4a1);
#
#
#
#         marker_7825bc17482eda9da3b6ce797faa257f.bindPopup(popup_c47bcff7cbf63c5cc4fabb4aebee141e)
#         ;
#
#
#
#
#             var marker_9a50f03fa5e9be5008e6070e6d3afcca = L.marker(
#                 [-40.85444444444445, -71.61611111111111],
#                 {}
#             ).addTo(map_783d93e2b63328be739a31aa3aa462e8);
#
#
#             var icon_c42422e704fc4f940a87e9a1b7966830 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9a50f03fa5e9be5008e6070e6d3afcca.setIcon(icon_c42422e704fc4f940a87e9a1b7966830);
#
#
#         var popup_99fc81ca5b2643a2a8e9d06856604b2d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_10e8f7cc17381d8d1db8b641ce21ccfe = $(`&lt;div id=&quot;html_10e8f7cc17381d8d1db8b641ce21ccfe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lago Nahuel Huapi&lt;/div&gt;`)[0];
#                 popup_99fc81ca5b2643a2a8e9d06856604b2d.setContent(html_10e8f7cc17381d8d1db8b641ce21ccfe);
#
#
#
#         marker_9a50f03fa5e9be5008e6070e6d3afcca.bindPopup(popup_99fc81ca5b2643a2a8e9d06856604b2d)
#         ;
#
#
#
#
#             var marker_e3d01e6b9cf3125fa0a7ac611113bf14 = L.marker(
#                 [-45.414722222222224, -69.197777777

# %% [markdown]
# # 5. Armá tu mapa
# Con el dataset elegido mostrá los datos en un mapa

# %% [markdown]
# ## Primero encontrá los nombres de las columnas donde están las coordenadas

# %%
#pone acá el código
import pandas as pd
file_data=pd.read_csv('ar-airports(1).csv')
file_data.columns
# Out:
# Index(['id', 'ident', 'type', 'name', 'latitude_deg', 'longitude_deg',
#        'elevation_ft', 'continent', 'country_name', 'iso_country',
#        'region_name', 'iso_region', 'local_region', 'municipality',
#        'scheduled_service', 'gps_code', 'iata_code', 'local_code', 'home_link',
#        'wikipedia_link', 'keywords', 'score', 'last_updated'],
#       dtype='object')

# %% [markdown]
# ## Segundo creá tu mapa **base**

# %%
# pone acá el codigo aca
mapa = generar_mapa()
def agregar_marca_lago(row):
    folium.Marker(
        [row['latitude_deg'], row['longitude_deg']],
        popup=row['name'],
        icon=folium.Icon()
        ).add_to(mapa)
file_data.apply(agregar_marca_lago, axis=1)
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8d1e6f90254db57a850774161dd3883e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8d1e6f90254db57a850774161dd3883e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8d1e6f90254db57a850774161dd3883e = L.map(
#                 &quot;map_8d1e6f90254db57a850774161dd3883e&quot;,
#                 {
#                     center: [-33.457606, -65.346857],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     name: &quot;es&quot;,
#                 }
#             );
#             L.control.scale().addTo(map_8d1e6f90254db57a850774161dd3883e);
#
#
#
#
#
#             var tile_layer_497a50e2dbfb9bfa2e4d01cbdb1d94a9 = L.tileLayer(
#                 &quot;https://wms.ign.gob.ar/geoserver/gwc/service/tms/1.0.0/capabaseargenmap@EPSG%3A3857@png/{z}/{x}/{-y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors, \u0026copy; \u003ca href=\&quot;https://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_497a50e2dbfb9bfa2e4d01cbdb1d94a9.addTo(map_8d1e6f90254db57a850774161dd3883e);
#
#
#             var marker_9ffbda80a0ec3594da031c2863992616 = L.marker(
#                 [-34.8222, -58.5358],
#                 {}
#             ).addTo(map_8d1e6f90254db57a850774161dd3883e);
#
#
#             var icon_b3a0e40ba0fd308f4976948b170fa07c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9ffbda80a0ec3594da031c2863992616.setIcon(icon_b3a0e40ba0fd308f4976948b170fa07c);
#
#
#         var popup_861b772a92bb17a0d597343f50d24c7a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d3a8725117ad46c21b0b1334a36097fe = $(`&lt;div id=&quot;html_d3a8725117ad46c21b0b1334a36097fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Minister Pistarini International Airport&lt;/div&gt;`)[0];
#                 popup_861b772a92bb17a0d597343f50d24c7a.setContent(html_d3a8725117ad46c21b0b1334a36097fe);
#
#
#
#         marker_9ffbda80a0ec3594da031c2863992616.bindPopup(popup_861b772a92bb17a0d597343f50d24c7a)
#         ;
#
#
#
#
#             var marker_b4023141c7940ed47b2658730ea6bf7b = L.marker(
#                 [-34.5592, -58.4156],
#                 {}
#             ).addTo(map_8d1e6f90254db57a850774161dd3883e);
#
#
#             var icon_b43f4a66729dfe9a367a0288368e92d1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b4023141c7940ed47b2658730ea6bf7b.setIcon(icon_b43f4a66729dfe9a367a0288368e92d1);
#
#
#         var popup_72e6bba1f54f62dc4d237ed701ed6b59 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_47e3e731a3543652a510b877f1d8ff4e = $(`&lt;div id=&quot;html_47e3e731a3543652a510b877f1d8ff4e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Jorge Newbery Airpark&lt;/div&gt;`)[0];
#                 popup_72e6bba1f54f62dc4d237ed701ed6b59.setContent(html_47e3e731a3543652a510b877f1d8ff4e);
#
#
#
#         marker_b4023141c7940ed47b2658730ea6bf7b.bindPopup(popup_72e6bba1f54f62dc4d237ed701ed6b59)
#         ;
#
#
#
#
#             var marker_e41b838774a6906eb74743a63ceab337 = L.marker(
#                 [-54.8433, -68.2958],
#                 {}
#             ).addTo(map_8d1e6f90254db57a850774161dd3883e);
#
#
#             var icon_d1359948d72c75395d11db8f55d4f01b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e41b838774a6906eb74743a63ceab337.setIcon(icon_d1359948d72c75395d11db8f55d4f01b);
#
#
#         var popup_0925e324b276740aca2c7098ed44ae0a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_49416e3f7f52d60ee0014779eaa430bf = $(`&lt;div id=&quot;html_49416e3f7f52d60ee0014779eaa430bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Malvinas Argentinas Airport&lt;/div&gt;`)[0];
#                 popup_0925e324b276740aca2c7098ed44ae0a.setContent(html_49416e3f7f52d60ee0014779eaa430bf);
#
#
#
#         marker_e41b838774a6906eb74743a63ceab337.bindPopup(popup_0925e324b276740aca2c7098ed44ae0a)
#         ;
#
#
#
#
#             var marker_bbce9be053225729bc30531c7bf26ed3 = L.marker(
#                 [-50.2803, -72.053101],

# %% [markdown]
# ## Tercero agregá los puntos a tu mapa
